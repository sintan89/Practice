# %% [markdown]
# <a href="https://colab.research.google.com/github/sintan89/Practice/blob/main/Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Membaca file csv menggunakan pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 50)
table = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/penduduk_gender_head.csv")
table.head()
#Membuat bar chart
x_label = table['NAMA KELURAHAN']
plt.bar(x=np.arange(len(x_label)), height=table['LAKI-LAKI WNI'])
#Memberikan nilai axis
plt.xticks(np.arange(len(x_label)), table['NAMA KELURAHAN'], rotation=30)
#Menambah title dan label pada grafik
plt.xlabel('Kelurahan di Jakarta Pusat')
plt.ylabel('Jumlah Penduduk Laki-Laki')
plt.title('Persebaran Jumlah Penduduk Laki-Laki di Jakarta Pusat')
#Menampilkan grafik
plt.show()
